# %% [markdown]
# **MIPACE Feature Extraction**

# %%
import pandas as pd
import os 
import glob

# %%
path = r'visit_data'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)
big_frame
# Out:
#       participant_ID  visit_date Local Time         t     Rf     VT      VE  \
# 0           TR000105    20220207   14:35:51  00:00:01  34.48  0.495  17.069
# 1           TR000105    20220207   14:35:54  00:00:04  22.39  0.386   8.642
# 2           TR000105    20220207   14:35:56  00:00:06  31.58  0.215   6.789
# 3           TR000105    20220207   14:35:57  00:00:07  45.11  0.361  16.286
# 4           TR000105    20220207   14:35:59  00:00:09  39.74  0.478  18.993
# ...              ...         ...        ...       ...    ...    ...     ...
# 47156       TR000109    20220518        NaN  00:42:51  14.78  1.968  29.084
# 47157       TR000109    20220518        NaN  00:42:54  23.81  0.812  19.333
# 47158       TR000109    20220518        NaN  00:42:58  17.00  0.636  10.810
# 47159       TR000109    20220518        NaN  00:43:04  12.82  1.106  14.179
# 47160       TR000109    20220518        NaN  00:43:08  12.42  0.594   7.379
#
#          IV          VO2        VCO2  ...  mark Distance  Phase time  \
# 0       278   633.186579  436.671233  ...              0    00:00:00
# 1       423   243.632787  161.895202  ...              0    00:00:03
# 2       155   153.178058  111.653509  ...              0    00:00:05
# 3       434   490.898195  331.038084  ...              0    00:00:06
# 4       307   619.037790  425.697689  ...              0    00:00:08
# ...     ...          ...         ...  ...            ...         ...
# 47156  2069  1445.077557  735.174081  ...              0    00:19:37
# 47157   575   645.898690  468.487287  ...              0    00:19:40
# 47158   766   259.265612  204.591295  ...              0    00:19:44
# 47159  1279   441.029677  371.705650  ...              0    00:19:50
# 47160   333   219.458560  180.442652  ...              0    00:19:54
#
#        VO2/Kg%Pred    BR  VT/Ti   HRR  PaCO2_e   Dyspnea   SV e  CO e
# 0               48  79.1   0.81   NaN       35       NaN    NaN   NaN
# 1               18  89.4   0.45  89.0       30       NaN   45.3   3.6
# 2               12  91.7   0.26  89.0       24       NaN   30.3   2.4
# 3               37  80.1   0.55  91.0       30       NaN   80.6   6.2
# 4               46  76.8   0.89  91.0       33       NaN   94.8   7.3
# ...            ...   ...    ...   ...      ...       ...    ...   ...
# 47156           56  79.3   1.21  86.0       32  LEVEL_18  200.9  13.9
# 47157           25  86.3   0.93  86.0       32  LEVEL_18  119.7   8.3
# 47158           10  92.3   0.27  87.0       30  LEVEL_18   58.1   3.9
# 47159           17  89.9   0.39  88.0       34  LEVEL_18   92.0   6.2
# 47160            8  94.8   0.20  88.0       34  LEVEL_18   50.9   3.4
#
# [47161 rows x 94 columns]

# %%
#Split Up Dataframes
def create_dataframe_dictionary(parent_df):
    participant_registry = dict()
    for row in parent_df.itertuples():
        participant_registry[row.participant_ID] = dict()
    for row in parent_df.itertuples():
        participant_registry[row.participant_ID][row.visit_date] = []
    for row in parent_df.itertuples():
        participant_registry[row.participant_ID][row.visit_date].append(row)
    participant_df = dict()
    for participant_id, participant_data in participant_registry.items():
        for visit_date in participant_data.keys():
            participant_df[f'{participant_id}_{visit_date}'] = pd.DataFrame(participant_registry[participant_id][visit_date])
    print(participant_df.keys())
    return participant_df

participant_df = create_dataframe_dictionary(big_frame)
participant_df['TR000105_20220207']
# Out:
# dict_keys(['TR000105_20220207', 'TR000105_20220517', 'TR000105_20220920', 'TR000106_20220420', 'TR000106_20220208', 'TR000106_20220823', 'TR000102_20220204', 'TR000102_20220401', 'TR000102_20220630', 'TR000100_20220623', 'TR000100_20220331', 'TR000100_20220203', 'TR000104_20220627', 'TR000104_20220207', 'TR000104_20220314', 'TR000109_20220209', 'TR000109_20220824', 'TR000109_20220518', 'TR000107_20220519', 'TR000107_20220208', 'TR000107_20220805', 'TR000103_20220401', 'TR000103_20220204', 'TR000103_20220706', 'TR000101_20220203', 'TR000101_20220630', 'TR000101_20220331', 'TR000110_20220210', 'TR000110_20220428', 'TR000110_20220901', 'TR000108_20220209'])
#       Index participant_ID  visit_date        _3         t     Rf     VT  \
# 0         0       TR000105    20220207  14:35:51  00:00:01  34.48  0.495
# 1         1       TR000105    20220207  14:35:54  00:00:04  22.39  0.386
# 2         2       TR000105    20220207  14:35:56  00:00:06  31.58  0.215
# 3         3       TR000105    20220207  14:35:57  00:00:07  45.11  0.361
# 4         4       TR000105    20220207  14:35:59  00:00:09  39.74  0.478
# ...     ...            ...         ...       ...       ...    ...    ...
# 1484   1484       TR000105    20220207  15:24:44  00:48:54   7.63  0.565
# 1485   1485       TR000105    20220207  15:24:46  00:48:56  19.35  0.402
# 1486   1486       TR000105    20220207  15:24:48  00:48:58  24.90  0.360
# 1487   1487       TR000105    20220207  15:24:49  00:48:59  41.38  0.944
# 1488   1488       TR000105    20220207  15:24:57  00:49:07  10.07  0.506
#
#           VE   IV          VO2  ...  _85       _86  _87    BR   _89   HRR  \
# 0     17.069  278   633.186579  ...    0  00:00:00   48  79.1  0.81   NaN
# 1      8.642  423   243.632787  ...    0  00:00:03   18  89.4  0.45  89.0
# 2      6.789  155   153.178058  ...    0  00:00:05   12  91.7  0.26  89.0
# 3     16.286  434   490.898195  ...    0  00:00:06   37  80.1  0.55  91.0
# 4     18.993  307   619.037790  ...    0  00:00:08   46  76.8  0.89  91.0
# ...      ...  ...          ...  ...  ...       ...  ...   ...   ...   ...
# 1484   4.313  784   161.262790  ...    0  00:19:51   12  94.7  0.35  70.0
# 1485   7.781  345   233.942437  ...    0  00:19:53   18  90.5  0.23  70.0
# 1486   8.963  215   262.451382  ...    0  00:19:55   20  89.0  0.63  70.0
# 1487  39.062  370  1532.565196  ...    0  00:19:56  115  52.2  1.57  70.0
# 1488   5.094  846   190.259985  ...    0  00:20:04   14  93.8  0.58  75.0
#
#       PaCO2_e   Dyspnea    _93   _94
# 0          35       NaN    NaN   NaN
# 1          30       NaN   45.3   3.6
# 2          24       NaN   30.3   2.4
# 3          30       NaN   80.6   6.2
# 4          33       NaN   94.8   7.3
# ...       ...       ...    ...   ...
# 1484       35  LEVEL_19   25.6   2.5
# 1485       32  LEVEL_19   35.3   3.5
# 1486       34  LEVEL_19   38.9   3.8
# 1487       38  LEVEL_19  124.5  12.2
# 1488       34  LEVEL_19   31.1   2.9
#
# [1489 rows x 95 columns]

# %%
def test_keys(df_dictionary):
    for key, values in df_dictionary.items():
        for row in values.itertuples():
            assert key == f'{row.participant_ID}_{row.visit_date}'
    return True

test_keys(participant_df)
# Out:
# True

# %%
#Create VO2 Outcome DF
def create_outcome_df(dictionary_df):
    id_list = list(dictionary_df.keys())
    result_df = pd.DataFrame({
    "participant_visit_id": id_list,
    "VO2_peak": None,
    "VO2/kgPeak": None,
    "True VO2max": None,
    "VO2Peak start time- global": None,
    "VO2Peak end time- global": None,
    "VO2Peak start time- local": None,
    "VO2Peak end time- local": None,
    "RQPeak": None,
    "HRPeak": None,
    "GradePeak": None,
    "SpeedPeak": None,
    "MarkerPeak": None,
    "EEMPeak": None,
    "Fat%Peak": None,
    "CHO%Peak": None,
    "Lactate-VO2Peak": None,
    "RPE-VO2peak": None,
    })

    # Set participant_id as the index
    result_df.set_index("participant_visit_id", inplace=True)
    return result_df
create_outcome_df(participant_df)
VO2_outcome_df = create_outcome_df(participant_df)
VO2_outcome_df
# Out:
#                      VO2_peak VO2/kgPeak True VO2max  \
# participant_visit_id
# TR000105_20220207        None       None        None
# TR000105_20220517        None       None        None
# TR000105_20220920        None       None        None
# TR000106_20220420        None       None        None
# TR000106_20220208        None       None        None
# TR000106_20220823        None       None        None
# TR000102_20220204        None       None        None
# TR000102_20220401        None       None        None
# TR000102_20220630        None       None        None
# TR000100_20220623        None       None        None
# TR000100_20220331        None       None        None
# TR000100_20220203        None       None        None
# TR000104_20220627        None       None        None
# TR000104_20220207        None       None        None
# TR000104_20220314        None       None        None
# TR000109_20220209        None       None        None
# TR000109_20220824        None       None        None
# TR000109_20220518        None       None        None
# TR000107_20220519        None       None        None
# TR000107_20220208        None       None        None
# TR000107_20220805        None       None        None
# TR000103_20220401        None       None        None
# TR000103_20220204        None       None        None
# TR000103_20220706        None       None        None
# TR000101_20220203        None       None        None
# TR000101_20220630        None       None        None
# TR000101_20220331        None       None        None
# TR000110_20220210        None       None        None
# TR000110_20220428        None       None        None
# TR000110_20220901        None       None        None
# TR000108_20220209        None       None        None
#
#                      VO2Peak start time- global VO2Peak end time- global  \
# participant_visit_id
# TR000105_20220207                          None                     None
# TR000105_20220517                          None                     None
# TR000105_20220920                          None                     None
# TR000106_20220420                          None                     None
# TR000106_20220208                          None                     None
# TR000106_20220823                          None                     None
# TR000102_20220204                          None                     None
# TR000102_20220401                          None                     None
# TR000102_20220630                          None                     None
# TR000100_20220623                          None                     None
# TR000100_20220331                          None                     None
# TR000100_20220203                          None                     None
# TR000104_20220627                          None                     None
# TR000104_20220207                          None                     None
# TR000104_20220314                          None                     None
# TR000109_20220209                          None                     None
# TR000109_20220824                          None                     None
# TR000109_20220518                          None                     None
# TR000107_20220519                          None                     None
# TR000107_20220208                          None                     None
# TR000107_20220805                          None                     None
# TR000103_20220401                          None                     None
# TR000103_20220204                          None                     None
# TR000103_20220706                          None                     None
# TR000106_20220420        None            None        None
# TR000106_20220208        None            None        None
# TR000106_20220823        None            None        None
# TR000102_20220204        None            None        None
# TR000102_20220401        None            None        None
# TR000102_20220630        None            None        None
# TR000100_20220623        None            None        None
# TR000100_20220331        None            None        None
# TR000100_20220203        None            None        None
# TR000104_20220627        None            None        None
# TR000104_20220207        None            None        None
# TR000104_20220314        None            None        None
# TR000109_20220209        None            None        None
# TR000109_20220824        None            None        None
# TR000109_20220518        None            None        None
# TR000107_20220519        None            None        None
# TR000107_20220208        None            None        None
# TR000107_20220805        None            None        None
# TR000103_20220401        None            None        None
# TR000103_20220204        None            None        None
# TR000103_20220706        None            None        None
# TR000101_20220203        None            None        None
# TR000101_20220630        None            None        None
# TR000101_20220331        None            None        None
# TR000110_20220210        None            None        None
# TR000110_20220428        None            None        None
# TR000110_20220901        None            None        None
# TR000108_20220209        None            None        None

# %%
# Get Visit Number
VO2_outcome_df['ID'] = VO2_outcome_df.index.str.split('_').str[0]
VO2_outcome_df['Visit Date'] = VO2_outcome_df.index.str.split('_').str[1]
VO2_outcome_df = VO2_outcome_df.sort_values(by=['ID', 'Visit Date'])
VO2_outcome_df['Visit Number'] = VO2_outcome_df.groupby('ID').cumcount()+1
VO2_outcome_df[['ID', 'Visit Date', 'Visit Number']].head()
# Out:
#                             ID Visit Date  Visit Number
# participant_visit_id
# TR000100_20220203     TR000100   20220203             1
# TR000100_20220331     TR000100   20220331             2
# TR000100_20220623     TR000100   20220623             3
# TR000101_20220203     TR000101   20220203             1
# TR000101_20220331     TR000101   20220331             2

# %%
# def get_VO2_peak(df_dictionary, result_df):
#     id_list = list(result_df.index)
#     for id in id_list:
#         df = df_dictionary[id]
        
#         # Convert 'timestamp' to seconds elapsed
#         df['seconds_elapsed'] = df['t'].apply(
#             lambda x: int(x.split(':')[0]) * 3600 + int(x.split(':')[1]) * 60 + int(x.split(':')[2])
#         )
        
#         # Initialize variables for tracking peak
#         peak_value = float('-inf')
#         peak_start_time = None
#         peak_end_time = None

#         # Iterate through each row to compute the rolling mean based on a 30-second window
#         for i, current_row in df.iterrows():
#             current_time = current_row['seconds_elapsed']
#             window_end = current_time
#             window_start = current_time - 30
            
#             # Select rows within the 30-second window
#             window_data = df[(df['seconds_elapsed'] >= window_start) & (df['seconds_elapsed'] <= window_end)]['VO2']
#             rolling_mean = window_data.mean()

#             # Update the peak value and corresponding time window
#             if rolling_mean > peak_value:
#                 peak_value = rolling_mean
#                 peak_start_time = window_start
#                 peak_end_time = window_end

#         # Record results in the result DataFrame
#         result_df.loc[id, 'VO2_peak'] = peak_value
#         result_df.loc[id, 'VO2Peak start time- global'] = peak_start_time
#         result_df.loc[id, 'VO2Peak end time- global'] = peak_end_time

#     return result_df


# VO2_outcome_df = get_VO2_peak(participant_df,VO2_outcome_df)
# VO2_outcome_df

# %%
def get_VO2_kg_peak(df_dictionary, result_df):
    id_list = list(result_df.index)
    for id in id_list:
        df = df_dictionary[id]
        
        # Convert 'timestamp' to seconds elapsed
        df['seconds_elapsed'] = df['t'].apply(
            lambda x: int(x.split(':')[0]) * 3600 + int(x.split(':')[1]) * 60 + int(x.split(':')[2])
        )
        
        # Initialize variables for tracking VO2_peak and VO2/kgPeak
        peak_value = float('-inf')
        peak_start_time = None
        peak_end_time = None
        kg_peak_value = None

        # Iterate through each row to compute the rolling mean based on a 30-second window
        for i, current_row in df.iterrows():
            current_time = current_row['seconds_elapsed']
            window_end = current_time
            window_start = current_time - 30
            
            # Select rows within the 30-second window
            window_data_VO2 = df[(df['seconds_elapsed'] >= window_start) & (df['seconds_elapsed'] <= window_end)]['VO2']
            rolling_mean_VO2 = window_data_VO2.mean()

            # Update the peak value and corresponding time window
            if rolling_mean_VO2 > peak_value:
                peak_value = rolling_mean_VO2
                peak_start_time = window_start
                peak_end_time = window_end

                # Find the rolling mean of the _16 column for the same interval
                window_data_16 = df[(df['seconds_elapsed'] >= window_start) & (df['seconds_elapsed'] <= window_end)]['_16']
                kg_peak_value = window_data_16.mean()

        # Convert seconds back to HH:MM:SS format
        def seconds_to_hhmmss(seconds):
            hours = seconds // 3600
            minutes = (seconds % 3600) // 60
            seconds = seconds % 60
            return f"{hours:02}:{minutes:02}:{seconds:02}"

        # Record results in the result DataFrame
        result_df.loc[id, 'VO2_peak'] = peak_value
        result_df.loc[id, 'VO2Peak start time- global'] = seconds_to_hhmmss(peak_start_time)
        result_df.loc[id, 'VO2Peak end time- global'] = seconds_to_hhmmss(peak_end_time)
        result_df.loc[id, 'VO2/kgPeak'] = kg_peak_value
    return result_df

VO2_outcome_df = get_VO2_kg_peak(participant_df, VO2_outcome_df)
VO2_outcome_df
# Out:
#                          VO2_peak VO2/kgPeak True VO2max  \
# participant_visit_id
# TR000105_20220207     2396.956179  54.352381        None
# TR000105_20220517     2433.322279  53.716087        None
# TR000105_20220920     2408.590657  53.883333        None
# TR000106_20220420     3861.439281    56.4544        None
# TR000106_20220208     3868.569068  54.640357        None
# TR000106_20220823     3650.909781      53.61        None
# TR000102_20220204     3547.730784  54.329167        None
# TR000102_20220401      3803.85079    59.0656        None
# TR000102_20220630     3789.272083    56.7264        None
# TR000100_20220623      3447.64189  66.685769        None
# TR000100_20220331     3443.011822  67.247059        None
# TR000100_20220203     3103.659316  59.572174        None
# TR000104_20220627     3261.158701  55.273636        None
# TR000104_20220207     3285.043512  56.832727        None
# TR000104_20220314     3381.121096  57.404091        None
# TR000109_20220209     3672.724523  46.726429        None
# TR000109_20220824     3869.638539  49.232963        None
# TR000109_20220518     3392.312297  43.435909        None
# TR000107_20220519     3850.185862  54.534848        None
# TR000107_20220208     4107.655889  56.039062        None
# TR000107_20220805     4200.408595  59.327879        None
# TR000103_20220401     3033.140285    52.5675        None
# TR000103_20220204     3224.178845     56.965        None
# TR000103_20220706     3114.803149   53.51875        None
# TR000101_20220203     2651.252137    47.5136        None
# TR000101_20220630     2573.773731  45.634074        None
# TR000101_20220331     2647.141505  47.439655        None
# TR000110_20220210     3251.510383  48.821034        None
# TR000110_20220428     3100.981981  46.492069        None
# TR000110_20220901     3174.688384  47.032258        None
# TR000108_20220209     2628.387511  39.643636        None
#        '_71', '_72', '_73', '_74', '_75', '_76', 'Ti', 'Te', 'Ttot', '_80',
#        '_81', 'LogVE', '_83', '_84', '_85', '_86', '_87', 'BR', '_89', 'HRR',
#        'PaCO2_e', 'Dyspnea', '_93', '_94'],
#       dtype='object')

# %%
#Create Result Dataframes
def create_results_dictionary(parent_df):
    participant_registry = dict()
    for row in parent_df.itertuples():
        participant_registry[row.participant_ID] = dict()
    for row in parent_df.itertuples():
        participant_registry[row.participant_ID][row.visit_date] = []
    participant_result_df = dict()
    columns = ["V02max", "LT1", "LT2", "VT1", "VT2", "Stage 1", "Stage 2", "Stage 3", "... Stage X"]
    rows = [
        "VO2 (mL/min/kg)",
        "Velocity (km/h)",
        "Grade (%)",
        "Stage (#)",
        "RPE (#)",
        "HR (bpm)",
        "Lactate (mmol/L)",
        "RQ",
        "True VO2max? Y/N",
        "Reach Steady State?",
    ]
    for participant_id, participant_data in participant_registry.items():
        for visit_date in participant_data.keys():
            participant_result_df[f'{participant_id}_{visit_date}'] = pd.DataFrame(columns=columns, index=rows)
    print(participant_df.keys())
    return participant_result_df

participant_result_df = create_results_dictionary(big_frame)
participant_result_df['TR000105_20220207']
# Out:
# dict_keys(['TR000105_20220207', 'TR000105_20220517', 'TR000105_20220920', 'TR000106_20220420', 'TR000106_20220208', 'TR000106_20220823', 'TR000102_20220204', 'TR000102_20220401', 'TR000102_20220630', 'TR000100_20220623', 'TR000100_20220331', 'TR000100_20220203', 'TR000104_20220627', 'TR000104_20220207', 'TR000104_20220314', 'TR000109_20220209', 'TR000109_20220824', 'TR000109_20220518', 'TR000107_20220519', 'TR000107_20220208', 'TR000107_20220805', 'TR000103_20220401', 'TR000103_20220204', 'TR000103_20220706', 'TR000101_20220203', 'TR000101_20220630', 'TR000101_20220331', 'TR000110_20220210', 'TR000110_20220428', 'TR000110_20220901', 'TR000108_20220209'])
#                     V02max  LT1  LT2  VT1  VT2 Stage 1 Stage 2 Stage 3  \
# VO2 (mL/min/kg)        NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# Velocity (km/h)        NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# Grade (%)              NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# Stage (#)              NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# RPE (#)                NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# HR (bpm)               NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# Lactate (mmol/L)       NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# RQ                     NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# True VO2max? Y/N       NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
# Reach Steady State?    NaN  NaN  NaN  NaN  NaN     NaN     NaN     NaN
#
#                     ... Stage X
# VO2 (mL/min/kg)             NaN
# Velocity (km/h)             NaN
# Grade (%)                   NaN
# Stage (#)                   NaN
# RPE (#)                     NaN
# HR (bpm)                    NaN
# Lactate (mmol/L)            NaN
# RQ                          NaN
# True VO2max? Y/N            NaN
# Reach Steady State?         NaN
